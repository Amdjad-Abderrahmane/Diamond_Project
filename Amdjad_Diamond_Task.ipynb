# %% [markdown]
# ![](logo1.jpg)

# %% [markdown]
# # Task #9

# %% [markdown]
# ***
# # 1- Get the Data
# ***

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Read train.csv as a dataframe called Diamond_Price.**

# %%
Diamond_Price = pd.read_csv("/content/train.csv")

# %% [markdown]
# ***
# # 2- Discover and visualize the data
# ***

# %% [markdown]
# ## A- Data discovery

# %% [markdown]
# #### 1-Top five rows using the DataFrame’s head() method

# %%
Diamond_Price.head()
# Out:
#    Id  carat      cut color clarity  depth  table  price     x     y     z
# 0   1   1.06    Ideal     I     SI2   61.8   57.0   4270  6.57  6.60  4.07
# 1   2   1.51  Premium     G    VVS2   60.9   58.0  15164  7.38  7.42  4.51
# 2   3   0.32    Ideal     F     VS2   61.3   56.0    828  4.43  4.41  2.71
# 3   4   0.53    Ideal     G     VS2   61.2   56.0   1577  5.19  5.22  3.19
# 4   5   0.70  Premium     H    VVS2   61.0   57.0   2596  5.76  5.72  3.50

# %% [markdown]
# #### 2-Quick description of the data

# %%
Diamond_Price.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43152 entries, 0 to 43151
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Id       43152 non-null  int64
#  1   carat    43152 non-null  float64
#  2   cut      43152 non-null  object
#  3   color    43152 non-null  object
#  4   clarity  43152 non-null  object
#  5   depth    43152 non-null  float64
#  6   table    43152 non-null  float64
#  7   price    43152 non-null  int64
#  8   x        43152 non-null  float64
#  9   y        43152 non-null  float64
#  10  z        43152 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 3.6+ MB

# %% [markdown]
# #### 3-Categorical columns

# %%
Diamond_Price["cut"].value_counts()
# Out:
# Ideal        17203
# Premium      11113
# Very Good     9658
# Good          3881
# Fair          1297
# Name: cut, dtype: int64

# %%
Diamond_Price["color"].value_counts()
# Out:
# G    9060
# E    7832
# F    7633
# H    6651
# D    5421
# I    4265
# J    2290
# Name: color, dtype: int64

# %%
Diamond_Price["clarity"].value_counts()
# Out:
# SI1     9298
# VS2     8759
# SI2     6623
# VS1     5773
# VVS2    3650
# VVS1    2603
# IF      1305
# I1       544
# Name: clarity, dtype: int64

# %% [markdown]
# #### 4-Removing the "ID" column for clarity's sake

# %%
Diamond_Price.drop(columns=["Id"], inplace=True)

# %% [markdown]
# #### 5-Summary of the numerical attributes.

# %%
Diamond_Price.describe()
# Out:
#               carat         depth         table         price             x  \
# count  43152.000000  43152.000000  43152.000000  43152.000000  43152.000000
# mean       0.797855     61.747177     57.458347   3929.491912      5.731568
# std        0.473594      1.435454      2.233904   3985.527795      1.121279
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    947.750000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5312.000000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#                   y             z
# count  43152.000000  43152.000000
# mean       5.735018      3.538568
# std        1.148809      0.708238
# min        0.000000      0.000000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max       58.900000     31.800000

# %% [markdown]
# ## B- Data visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### 1-Hist plot for Diamond_Price dataframe.

# %%
Diamond_Price.hist(figsize = (20,10),bins = 50)
plt.show()

# %% [markdown]
# #### 2-Scatter plot between deifferent columns

# %%
Diamond_Price.plot(kind = 'scatter',x='depth',y='table',alpha=0.4, figsize= (7,4))
# Out:
# <Axes: xlabel='depth', ylabel='table'>

# %%
Diamond_Price.plot(kind = 'scatter',x='x',y='y',alpha=0.4, figsize= (7,4))
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
Diamond_Price.plot(kind = 'scatter',x='x',y='z',alpha=0.4, figsize= (7,4))
# Out:
# <Axes: xlabel='x', ylabel='z'>

# %%
Diamond_Price.plot(kind = 'scatter',x='y',y='z',alpha=0.4, figsize= (7,4))
# Out:
# <Axes: xlabel='y', ylabel='z'>

# %% [markdown]
# #### 3-Plots with radius of each circle represent the dimonds’s weight or carat (option s), and the color represents the price (option c).

# %%
Diamond_Price.plot(kind = 'scatter',x='depth',y='table',alpha=0.4,
             s= Diamond_Price['carat']*50, c= 'price', 
             cmap = plt.get_cmap('jet'),colorbar = True, sharex = False,figsize = (7,4))
# Out:
# <Axes: xlabel='depth', ylabel='table'>

# %%
Diamond_Price.plot(kind = 'scatter',x='x',y='y',alpha=0.4,
             s= Diamond_Price['carat']*50, c= 'price', 
             cmap = plt.get_cmap('jet'),colorbar = True, sharex = False,figsize = (7,4))
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
Diamond_Price.plot(kind = 'scatter',x='x',y='z',alpha=0.4,
             s= Diamond_Price['carat']*50, c= 'price', 
             cmap = plt.get_cmap('jet'),colorbar = True, sharex = False,figsize = (7,4))
# Out:
# <Axes: xlabel='x', ylabel='z'>

# %%
Diamond_Price.plot(kind = 'scatter',x='y',y='z',alpha=0.4,
             s= Diamond_Price['carat']*50, c= 'price', 
             cmap = plt.get_cmap('jet'),colorbar = True, sharex = False,figsize = (7,4))
# Out:
# <Axes: xlabel='y', ylabel='z'>

# %% [markdown]
# #### 4-Correlation between all continuous numeric variables.

# %%
Diamond_Price.corr()
# Out:
# <ipython-input-29-f5d05fdb2bd2>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   Diamond_Price.corr()
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.023944  0.182889  0.921911  0.975760  0.947060  0.948923
# depth  0.023944  1.000000 -0.302794 -0.013137 -0.029601 -0.033354  0.090834
# table  0.182889 -0.302794  1.000000  0.128501  0.197342  0.184310  0.150746
# price  0.921911 -0.013137  0.128501  1.000000  0.885181  0.861354  0.857665
# x      0.975760 -0.029601  0.197342  0.885181  1.000000  0.968954  0.965677
# y      0.947060 -0.033354  0.184310  0.861354  0.968954  1.000000  0.942670
# z      0.948923  0.090834  0.150746  0.857665  0.965677  0.942670  1.000000

# %% [markdown]
# #### 5-Converting the correlation matrix to a heatmap plot

# %%
plt.figure(figsize=(8, 4))

heatmap = sns.heatmap(Diamond_Price.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')

heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':14}, pad=12);
# Out:
# <ipython-input-30-8c1657e5adec>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(Diamond_Price.corr(), vmin=-1, vmax=1, annot=True, cmap='BrBG')

# %% [markdown]
# #### 6-Checking for correlation between attributes.

# %%
from pandas.plotting import scatter_matrix

attributes = ["price", "carat", "depth", "table","x","y","z"]


scatter_matrix(Diamond_Price[attributes],figsize = (12,6))
# Out:
# array([[<Axes: xlabel='price', ylabel='price'>,
#         <Axes: xlabel='carat', ylabel='price'>,
#         <Axes: xlabel='depth', ylabel='price'>,
#         <Axes: xlabel='table', ylabel='price'>,
#         <Axes: xlabel='x', ylabel='price'>,
#         <Axes: xlabel='y', ylabel='price'>,
#         <Axes: xlabel='z', ylabel='price'>],
#        [<Axes: xlabel='price', ylabel='carat'>,
#         <Axes: xlabel='carat', ylabel='carat'>,
#         <Axes: xlabel='depth', ylabel='carat'>,
#         <Axes: xlabel='table', ylabel='carat'>,
#         <Axes: xlabel='x', ylabel='carat'>,
#         <Axes: xlabel='y', ylabel='carat'>,
#         <Axes: xlabel='z', ylabel='carat'>],
#        [<Axes: xlabel='price', ylabel='depth'>,
#         <Axes: xlabel='carat', ylabel='depth'>,
#         <Axes: xlabel='depth', ylabel='depth'>,
#         <Axes: xlabel='table', ylabel='depth'>,
#         <Axes: xlabel='x', ylabel='depth'>,
#         <Axes: xlabel='y', ylabel='depth'>,
#         <Axes: xlabel='z', ylabel='depth'>],
#        [<Axes: xlabel='price', ylabel='table'>,
#         <Axes: xlabel='carat', ylabel='table'>,
#         <Axes: xlabel='depth', ylabel='table'>,
#         <Axes: xlabel='table', ylabel='table'>,
#         <Axes: xlabel='x', ylabel='table'>,
#         <Axes: xlabel='y', ylabel='table'>,
#         <Axes: xlabel='z', ylabel='table'>],
#        [<Axes: xlabel='price', ylabel='x'>,
#         <Axes: xlabel='carat', ylabel='x'>,
#         <Axes: xlabel='depth', ylabel='x'>,
#         <Axes: xlabel='table', ylabel='x'>,
#         <Axes: xlabel='x', ylabel='x'>, <Axes: xlabel='y', ylabel='x'>,
#         <Axes: xlabel='z', ylabel='x'>],
#        [<Axes: xlabel='price', ylabel='y'>,
#         <Axes: xlabel='carat', ylabel='y'>,
#         <Axes: xlabel='depth', ylabel='y'>,
#         <Axes: xlabel='table', ylabel='y'>,
#         <Axes: xlabel='x', ylabel='y'>, <Axes: xlabel='y', ylabel='y'>,
#         <Axes: xlabel='z', ylabel='y'>],
#        [<Axes: xlabel='price', ylabel='z'>,
#         <Axes: xlabel='carat', ylabel='z'>,
#         <Axes: xlabel='depth', ylabel='z'>,
#         <Axes: xlabel='table', ylabel='z'>,
#         <Axes: xlabel='x', ylabel='z'>, <Axes: xlabel='y', ylabel='z'>,
#         <Axes: xlabel='z', ylabel='z'>]], dtype=object)

# %% [markdown]
# #### 7-Pairplots

# %%
attributes = ["price", "carat", "depth", "table","clarity"]

# %%
sns.pairplot(Diamond_Price[attributes], hue="clarity", height = 2, plot_kws={"s": 3})

# %%
attributes = ["price", "carat", "depth", "table","cut"]

# %%
sns.pairplot(Diamond_Price[attributes], hue="cut", height = 2, plot_kws={"s": 3})

# %%
attributes = ["price", "carat", "depth", "table","color"]

# %%
sns.pairplot(Diamond_Price[attributes], hue="color", height = 2, plot_kws={"s": 3})

# %% [markdown]
# #### 8-Scatter plot between carat and price

# %%
Diamond_Price.plot(kind = 'scatter',x = 'carat',y='price',alpha = 0.1, figsize=(5,3))
# Out:
# <Axes: xlabel='carat', ylabel='price'>

# %% [markdown]
# #### 9-Scatter plot between price and xyz

# %%
Diamond_Price_Copy = Diamond_Price.copy()
Diamond_Price_Copy ['xyz'] = Diamond_Price_Copy['x'] * Diamond_Price_Copy['y'] * Diamond_Price_Copy['z']
Diamond_Price_Copy.plot(kind = 'scatter',x = 'price',y= 'xyz',alpha = 0.1, figsize=(5,3))
# Out:
# <Axes: xlabel='price', ylabel='xyz'>

# %% [markdown]
# #### 10-Boxplot to show the relation between the price and the categorical features

# %%
# (1) With the comumn 'cut'

# %%
plt.figure(figsize=(4,3))
sns.boxplot(x='price', y='cut', data=Diamond_Price)
# Out:
# <Axes: xlabel='price', ylabel='cut'>

# %%
# (2) With the comumn 'color'

# %%
plt.figure(figsize=(4,3))
sns.boxplot(x='price', y='color', data=Diamond_Price)
# Out:
# <Axes: xlabel='price', ylabel='color'>

# %%
# (2) With the comumn 'clarity'

# %%
plt.figure(figsize=(4,3))
sns.boxplot(x='price', y='clarity', data=Diamond_Price)
# Out:
# <Axes: xlabel='price', ylabel='clarity'>

# %% [markdown]
# ***
# # 3- Prepare the data
# ***

# %% [markdown]
# ## A- Data Cleaning

# %% [markdown]
# #### 1-Total count of missing values per column.

# %%
Diamond_Price.isna().sum()
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# #### 2-Check if there any zeros in dataframe.

# %%
(Diamond_Price == 0).sum(axis=0)
# Out:
# carat       0
# cut         0
# color       0
# clarity     0
# depth       0
# table       0
# price       0
# x           5
# y           4
# z          17
# dtype: int64

# %% [markdown]
# #### 3-Clearing the samples having zeros in the columns 'x','y' and 'z' from the dataframe

# %%
Diamond_Price = Diamond_Price[(Diamond_Price["x"] != 0) & (Diamond_Price["y"] != 0) & (Diamond_Price["z"] != 0)]

# %%
(Diamond_Price == 0).sum(axis=0)
# Out:
# carat      0
# cut        0
# color      0
# clarity    0
# depth      0
# table      0
# price      0
# x          0
# y          0
# z          0
# dtype: int64

# %% [markdown]
# #### 4-Removing Outliers

# %%
Q1_x,Q3_x=np.percentile(Diamond_Price['x'],[25,75])
IQR_x=Q3_x-Q1_x
    
min_x=Q1_x - 1.5*IQR_x
max_x=Q3_x + 1.5*IQR_x

print("limits of x",min_x, " ", max_x)

Q1_y,Q3_y=np.percentile(Diamond_Price['y'],[25,75])
IQR_y=Q3_y-Q1_y
    
min_y=Q1_y-1.5*IQR_y
max_y=Q3_y+1.5*IQR_y

print("limits of y",min_y, " ", max_y)

Q1_z,Q3_z=np.percentile(Diamond_Price['z'],[25,75])
IQR_z=Q3_z-Q1_z
    
min_z=Q1_z-1.5*IQR_z
max_z=Q3_z+1.5*IQR_z

print("limits of z",min_z, " ", max_z)

Q1_c,Q3_c=np.percentile(Diamond_Price['carat'],[25,75])
IQR_c=Q3_c-Q1_c
    
min_c=Q1_c-1.5*IQR_c
max_c=Q3_c+1.5*IQR_c

print("limits of carat",min_c, " ", max_c)


Q1_t,Q3_t=np.percentile(Diamond_Price['table'],[25,75])
IQR_t=Q3_t-Q1_t

min_t=Q1_t-1.5*IQR_t
max_t=Q3_t+1.5*IQR_t

print("limits of table",min_t, " ", max_t)
# Out:
# limits of x 1.9649999999999999   9.285
# limits of y 1.9899999999999993   9.27
# limits of z 1.2150000000000003   5.734999999999999
# limits of carat -0.5599999999999999   2.0
# limits of table 51.5   63.5

# %%
#Dropping the outliers. 

Diamond_Price = Diamond_Price[(Diamond_Price["x"]> min_x) & (Diamond_Price["x"]<max_x)]
Diamond_Price = Diamond_Price[(Diamond_Price["y"]>min_y) & (Diamond_Price["y"]<max_y)]
Diamond_Price = Diamond_Price[(Diamond_Price["z"]>min_z) & (Diamond_Price["z"]<6.5)]

Diamond_Price.shape
# Out:
# (43115, 10)

# %%
Diamond_Price.describe()
# Out:
#               carat         depth         table         price             x  \
# count  43115.000000  43115.000000  43115.000000  43115.000000  43115.000000
# mean       0.796545     61.747454     57.457472   3923.326661      5.730238
# std        0.470337      1.434095      2.232713   3977.742892      1.116888
# min        0.200000     43.000000     43.000000    326.000000      3.730000
# 25%        0.400000     61.000000     56.000000    947.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2400.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5303.000000      6.540000
# max        3.110000     79.000000     95.000000  18823.000000      9.250000
#
#                   y             z
# count  43115.000000  43115.000000
# mean       5.731791      3.538321
# std        1.109006      0.689655
# min        3.680000      1.410000
# 25%        4.720000      2.910000
# 50%        5.710000      3.530000
# 75%        6.540000      4.040000
# max        9.200000      6.160000

# %% [markdown]
# ## B-Converting categorical features into numerical

# %%
Diamond_Price['cut'] = Diamond_Price['cut'].replace(['Fair'], 0)
Diamond_Price['cut'] = Diamond_Price['cut'].replace(['Good'], 1)
Diamond_Price['cut'] = Diamond_Price['cut'].replace(['Very Good'], 2)
Diamond_Price['cut'] = Diamond_Price['cut'].replace(['Premium'], 3)
Diamond_Price['cut'] = Diamond_Price['cut'].replace(['Ideal'], 4)

# %%
Diamond_Price['color'] = Diamond_Price['color'].replace(['D'], 6)
Diamond_Price['color'] = Diamond_Price['color'].replace(['E'], 5)
Diamond_Price['color'] = Diamond_Price['color'].replace(['F'], 4)
Diamond_Price['color'] = Diamond_Price['color'].replace(['G'], 3)
Diamond_Price['color'] = Diamond_Price['color'].replace(['H'], 2)
Diamond_Price['color'] = Diamond_Price['color'].replace(['I'], 1)
Diamond_Price['color'] = Diamond_Price['color'].replace(['J'], 0)

# %%
Diamond_Price['clarity'] = Diamond_Price['clarity'].replace(['I1'], 0)
Diamond_Price['clarity'] = Diamond_Price['clarity'].replace(['SI2'], 1)
Diamond_Price['clarity'] = Diamond_Price['clarity'].replace(['SI1'], 2)
Diamond_Price['clarity'] = Diamond_Price['clarity'].replace(['VS2'], 3)
Diamond_Price['clarity'] = Diamond_Price['clarity'].replace(['VS1'], 4)
Diamond_Price['clarity'] = Diamond_Price['clarity'].replace(['VVS2'],5)
Diamond_Price['clarity'] = Diamond_Price['clarity'].replace(['VVS1'], 6)
Diamond_Price['clarity'] = Diamond_Price['clarity'].replace(['IF'], 7)

# %% [markdown]
# # 4-Splitting data and applying pipelines for transformations

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.model_selection import train_test_split
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler

# %%
train_set, test_set = train_test_split(Diamond_Price, test_size=0.2, random_state=42)

Diamond_Price_Train = train_set.drop("price", axis=1)
Diamond_Price_labels = train_set["price"].copy()

num_attribs = list(Diamond_Price_Train)

# %%
num_pipeline = Pipeline([('Std_Scaler', StandardScaler())])

full_pipeline = ColumnTransformer([("num", num_pipeline, num_attribs)])

# %%
Diamond_Price_prepared = full_pipeline.fit_transform(Diamond_Price_Train)

# %% [markdown]
# # 5-Training and evaluating XGBoost model

# %% [markdown]
# ## 1-Using GridSearchCV to select the best hyperparameters

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
import time

params = { 'max_depth': [7,8,9,10],              # The best value : 8
           'n_estimators': [100,250,500,750],    # The best value : 250
           'colsample_bytree': [0.8,0.9,1],      # The best value : 0.9
           'subsample': [0.8,0.9],               # The best value : 0.8
          'eta':[0.01,0.04,0.01],                # The best value : 0.04
          'min_child_weight':[2,3],              # The best value : 3
          'gamma':[0.0],
          'lambda':[2],
          'alpha':[1]}

model = xgb.XGBRegressor()
grid = GridSearchCV(estimator=model, 
                   param_grid=params,
                   scoring='r2', 
                   verbose=1)
start = time.time()
grid.fit(Diamond_Price_prepared, Diamond_Price_labels)
end = time.time()
print(end-start)
print("Best parameters:", grid.best_params_)
print("Best Score (R2): ", (grid.best_score_))
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# 54.73285388946533
# Best parameters: {'alpha': 1, 'colsample_bytree': 0.8, 'eta': 0.04, 'gamma': 0.0, 'lambda': 2, 'max_depth': 8, 'min_child_weight': 3, 'n_estimators': 250, 'subsample': 0.8}
# Best Score (R2):  0.9823629323246047

# %%
XGB_Model = grid.best_estimator_

# %% [markdown]
# ## 2-Preparing the test set

# %%
Diamond_Price_Test = test_set.drop("price", axis=1)
Diamond_Price_Test_labels = test_set["price"].copy()

Diamond_Price_Test_num = Diamond_Price_Test
num_attribs = list(Diamond_Price_Test_num)

# %%
Diamond_Price_Test_Prepared = full_pipeline.transform(Diamond_Price_Test)

# %% [markdown]
# ## 3-Evaluation of the model on the train set and the test set

# %%
# Evaluation the train set with XGB 

XGB_pred = XGB_Model.predict(Diamond_Price_prepared)
XGB_mse = mean_squared_error(Diamond_Price_labels.values, XGB_pred)
XGB_rmse = np.sqrt(XGB_mse)
XGB_rmse
# Out:
# 366.951597728475

# %%
# Evaluation the test set with XGB 

XGB_pred = XGB_Model.predict(Diamond_Price_Test_Prepared)
XGB_mse = mean_squared_error(Diamond_Price_Test_labels.values, XGB_pred)
XGB_rmse = np.sqrt(XGB_mse)
XGB_rmse
# Out:
# 503.090095721825

# %% [markdown]
# # 6-Preparing sumbission

# %% [markdown]
# ## Reading the data

# %%
Test = pd.read_csv("/content/test.csv")

# %%
Test.head()
# Out:
#    Id  carat        cut color clarity  depth  table     x     y     z
# 0   1   0.34      Ideal     G    VVS2   61.1   57.0  4.52  4.48  2.75
# 1   2   0.71    Premium     E     VS2   62.7   58.0  5.74  5.68  3.58
# 2   3   0.44  Very Good     I     VS1   62.8   56.0  4.83  4.88  3.05
# 3   4   0.81    Premium     E     SI2   60.1   59.0  6.09  6.03  3.65
# 4   5   0.40      Ideal     G    VVS1   61.2   56.0  4.74  4.80  2.92

# %%
Test.describe()
# Out:
#                  Id         carat         depth         table             x  \
# count  10788.000000  10788.000000  10788.000000  10788.000000  10788.000000
# mean    5394.500000      0.798279     61.758315     57.452531      5.729514
# std     3114.371686      0.475700      1.421266      2.236933      1.123736
# min        1.000000      0.200000     54.000000     50.000000      0.000000
# 25%     2697.750000      0.400000     61.100000     56.000000      4.720000
# 50%     5394.500000      0.700000     61.800000     57.000000      5.700000
# 75%     8091.250000      1.040000     62.500000     59.000000      6.540000
# max    10788.000000      4.500000     79.000000     73.000000     10.230000
#
#                   y             z
# count  10788.000000  10788.000000
# mean       5.732559      3.539398
# std        1.115090      0.695483
# min        0.000000      0.000000
# 25%        4.727500      2.910000
# 50%        5.710000      3.520000
# 75%        6.540000      4.030000
# max       10.160000      6.720000

# %% [markdown]
# ## Preparing the data

# %%
Test_Id = Test[["Id"]]

# %%
Test.drop(columns=["Id"], inplace=True)

# %%
Test['cut'] = Test['cut'].replace(['Fair'], 0)
Test['cut'] = Test['cut'].replace(['Good'], 1)
Test['cut'] = Test['cut'].replace(['Very Good'], 2)
Test['cut'] = Test['cut'].replace(['Premium'], 3)
Test['cut'] = Test['cut'].replace(['Ideal'], 4)


Test['color'] = Test['color'].replace(['D'], 6)
Test['color'] = Test['color'].replace(['E'], 5)
Test['color'] = Test['color'].replace(['F'], 4)
Test['color'] = Test['color'].replace(['G'], 3)
Test['color'] = Test['color'].replace(['H'], 2)
Test['color'] = Test['color'].replace(['I'], 1)
Test['color'] = Test['color'].replace(['J'], 0)

Test['clarity'] = Test['clarity'].replace(['I1'], 0)
Test['clarity'] = Test['clarity'].replace(['SI2'], 1)
Test['clarity'] = Test['clarity'].replace(['SI1'], 2)
Test['clarity'] = Test['clarity'].replace(['VS2'], 3)
Test['clarity'] = Test['clarity'].replace(['VS1'], 4)
Test['clarity'] = Test['clarity'].replace(['VVS2'],5)
Test['clarity'] = Test['clarity'].replace(['VVS1'], 6)
Test['clarity'] = Test['clarity'].replace(['IF'], 7)

# %%
Test_num = Test
num_attribs = Test_num

Test_Prepared = full_pipeline.transform(num_attribs)

# %%
final_predictions = XGB_Model.predict(Test_Prepared)

# %%
final_predictions
# Out:
# array([  877.1761 ,  2819.2322 ,   838.75616, ...,  4334.6147 ,
#         4766.305  , 13257.708  ], dtype=float32)

# %% [markdown]
# ## Preparing the final file to submit

# %%
sample_submission = Test_Id

# %%
sample_submission["price"] = final_predictions.tolist()
# Out:
# <ipython-input-61-f3d8000edf4e>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_submission["price"] = final_predictions.tolist()

# %%
sample_submission
# Out:
#           Id         price
# 0          1    877.176086
# 1          2   2819.232178
# 2          3    838.756165
# 3          4   2820.158691
# 4          5   1129.646118
# ...      ...           ...
# 10783  10784   1745.883545
# 10784  10785   6742.004883
# 10785  10786   4334.614746
# 10786  10787   4766.305176
# 10787  10788  13257.708008
#
# [10788 rows x 2 columns]

# %%
sample_submission.to_csv("sample_submission.csv", index = None)
